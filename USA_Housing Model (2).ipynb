# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('USA_Housing.csv')
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
data.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
data.shape
# Out:
# (5000, 7)

# %% [markdown]
# Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
data.describe(include = 'object')
# Out:
#                                                   Address
# count                                                5000
# unique                                               5000
# top     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# freq                                                    1

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %% [markdown]
# Checking Missing Data

# %%
data.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
data.isnull().mean()
# Out:
# Avg. Area Income                0.0
# Avg. Area House Age             0.0
# Avg. Area Number of Rooms       0.0
# Avg. Area Number of Bedrooms    0.0
# Area Population                 0.0
# Price                           0.0
# Address                         0.0
# dtype: float64

# %% [markdown]
# Unique Data Analysis

# %%
#Numerical Data

numerical_data = data.select_dtypes(include = np.number).columns

for i in numerical_data:
    print(i,'\n')
    print(data[i].value_counts())
    print('\n\n')
    print("-------------------------------------------------------Next Column--------------------------------------------------")
# Out:
# Avg. Area Income
#
# Avg. Area Income
# 79545.458574    1
# 68735.436608    1
# 71635.473101    1
# 73211.136245    1
# 86249.993070    1
#                ..
# 66064.532823    1
# 59390.346824    1
# 64661.930276    1
# 73279.030904    1
# 65510.581804    1
# Name: count, Length: 5000, dtype: int64
#
#
#
# -------------------------------------------------------Next Column--------------------------------------------------
# Avg. Area House Age
#
# Avg. Area House Age
# 5.682861    1
# 7.721909    1
# 5.866996    1
# 6.501139    1
# 6.155403    1
#            ..
# 6.659562    1
# 5.664971    1
# 4.656696    1
# 5.902296    1
# 5.992305    1
# Name: count, Length: 5000, dtype: int64
#
#
#
# -------------------------------------------------------Next Column--------------------------------------------------
# Avg. Area Number of Rooms
#
# Avg. Area Number of Rooms
# 7.009188     1
# 7.621975     1
# 6.075987     1
# 10.280022    1
# 7.967184     1
#             ..
# 6.881398     1
# ...

# %%
#Categorical Data

categorical_data = data.select_dtypes(include = 'object').columns

for i in categorical_data:
    print(i, '\n')
    print(data[i].value_counts())
# Out:
# Address
#
# Address
# 208 Michael Ferry Apt. 674\nLaurabury, NE 37010-5101             1
# 314 Christopher Square Apt. 404\nLake Ronaldville, SD 42025      1
# 21042 Wilson Islands Suite 238\nFischerchester, MP 42425-4129    1
# Unit 8831 Box 5748\nDPO AE 73012-7314                            1
# 481 Kaitlin Mission Apt. 309\nJodystad, IA 16947                 1
#                                                                 ..
# 054 Carter Crescent Suite 674\nGlennport, WA 11140               1
# 8460 Kathleen Mission Apt. 482\nPort Amytown, KY 72016           1
# 3737 Hartman Rue\nReneestad, ID 69250-7718                       1
# 3465 Latoya Well\nNelsonmouth, MI 55741-4287                     1
# 37778 George Ridges Apt. 509\nEast Holly, NV 29290-3595          1
# Name: count, Length: 5000, dtype: int64

# %%
numerical_data
for i in numerical_data:
    plt.figure(figsize=(5,6))
    sns.countplot(data=data, x=i)
    plt.show()

# %%
'''for i in categorical_data:
    plt.figure(figsize=(5,6))
    sns.countplot(data=data, x=i)
    plt.show()'''
#skipped as the address is unique for each value
# Out:
# 'for i in categorical_data:\n    plt.figure(figsize=(5,6))\n    sns.countplot(data=data, x=i)\n    plt.show()'

# %%
def attribute_info(df_features):
    print(f'Description of features: \n\n {df_features.describe()} \n')
    print(f'Value counts: \n\n {df_features.value_counts()} \n')
    print(f'Unique features: \n\n {df_features.unique()} \n')
    print(f'Missing values: \n\n {df_features.isnull().sum()} \n')
    print(f'Missing values in %: \n\n {df_features.isnull().mean()} \n')

# %%
for col in data:
    print(f'\033[1m--------------------{col}------------------------\]')
    print('\n')
    attribute_info(data[col])
    print('\n\n')
# Out:
# --------------------Avg. Area Income------------------------\]
#
#
# Description of features:
#
#  count      5000.000000
# mean      68583.108984
# std       10657.991214
# min       17796.631190
# 25%       61480.562388
# 50%       68804.286404
# 75%       75783.338666
# max      107701.748378
# Name: Avg. Area Income, dtype: float64
#
# Value counts:
#
#  Avg. Area Income
# 79545.458574    1
# 68735.436608    1
# 71635.473101    1
# 73211.136245    1
# 86249.993070    1
#                ..
# 66064.532823    1
# 59390.346824    1
# 64661.930276    1
# 73279.030904    1
# 65510.581804    1
# Name: count, Length: 5000, dtype: int64
#
# Unique features:
#
#  [79545.45857432 79248.64245483 61287.06717866 ... 63390.6868855
#  68001.33123509 65510.58180367]
#
# Missing values:
#
#  0
#
# Missing values in %:
#
#  0.0
#
#
#
#
# --------------------Avg. Area House Age------------------------\]
#
#
# Description of features:
#
#  count    5000.000000
# mean        5.977222
# ...

# %% [markdown]
# Data Visualization

# %%
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
data.hist(figsize = (15, 10), bins = 700, color = 'b', alpha = 0.7)
plt.show()

# %% [markdown]
# Outlier Detection

# %%
plt.figure(figsize = (15, 10))
sns.boxplot(data)
# Out:
# <Axes: >

# %%
sns.boxplot(data['Avg. Area Income'])
# Out:
# <Axes: ylabel='Avg. Area Income'>

# %%
sns.boxplot(data['Avg. Area House Age'])
# Out:
# <Axes: ylabel='Avg. Area House Age'>

# %%
sns.boxplot(data['Avg. Area Number of Rooms'])
# Out:
# <Axes: ylabel='Avg. Area Number of Rooms'>

# %%
sns.boxplot(data['Area Population'])
# Out:
# <Axes: ylabel='Area Population'>

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data['Avg. Area Income'], color='m', linewidth=2)
plt.grid()
plt.title('Boxplot for Avg. Area Income')
plt.xlabel('X-Axis')
plt.ylabel('Income')
plt.yticks(np.arange(0, 105000, 5000))
plt.show()

# %%
data[40000 > data['Avg. Area Income']]
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 12        39033.809237             7.671755                   7.250029
# 39        17796.631190             4.949557                   6.713905
# 411       36100.444227             5.778489                   5.497450
# 844       39411.652788             4.385845                   7.047435
# 1271      37971.207566             4.291224                   5.807510
# 1459      35963.330809             3.438547                   8.264122
# 1597      39294.036523             5.928585                   5.960676
# 2025      38139.919045             5.577267                   6.348068
# 2092      35608.986237             6.935839                   7.827589
# 2242      38868.250311             6.965104                   8.966906
# 2597      38734.005216             5.641762                   6.297908
# 3069      35454.714659             6.855708                   6.018647
# ...

# %%
len(data[40000 > data['Avg. Area Income']][['Avg. Area Income', 'Price']].index)
# Out:
# 19

# %%
data[data['Avg. Area Income'] > 95500]
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 428       97112.361252             5.914725                   6.133646
# 558       99629.013581             5.431863                   7.351398
# 601       96807.436912             6.182168                   7.301724
# 693      107701.748378             7.143522                   8.518608
# 876       96395.321798             5.460823                   7.528098
# 962      101928.858060             4.829586                   9.039382
# 1096      97548.310413             5.460973                   6.609396
# 1264      96778.121065             4.569411                   7.827748
# 1516      95997.671100             6.685863                   6.993422
# 1734     104702.724257             5.575523                   6.932106
# 1891     101144.323930             6.350845                   7.231771
# 1957      96290.159673             5.166648                   8.317600
# ...

# %%
len(data[data['Avg. Area Income'] > 95500][['Area Population', 'Price']].index)
# Out:
# 26

# %%
data[data['Avg. Area Income'] < 40000][['Avg. Area Income', 'Price']].index
# Out:
# Index([  12,   39,  411,  844, 1271, 1459, 1597, 2025, 2092, 2242, 2597, 3069,
#        3144, 3183, 4449, 4716, 4744, 4844, 4855],
#       dtype='int64')

# %%
data[data['Avg. Area Income'] > 95500][['Area Population', 'Price']].index
# Out:
# Index([ 428,  558,  601,  693,  876,  962, 1096, 1264, 1516, 1734, 1891, 1957,
#        2300, 2383, 2719, 3483, 3541, 3611, 3670, 3798, 3945, 3947, 4087, 4158,
#        4206, 4400],
#       dtype='int64')

# %%
data.drop(index = [12,   39,  411,  844, 1271, 1459, 1597, 2025, 2092, 2242, 2597, 3069,
       3144, 3183, 4449, 4716, 4744, 4844, 4855,428,  558,  601,  693,  876,  962, 1096, 1264, 1516, 1734, 1891, 1957,
       2300, 2383, 2719, 3483, 3541, 3611, 3670, 3798, 3945, 3947, 4087, 4158,
       4206, 4400], inplace = True)

# %%
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data['Avg. Area Income'], color='m', linewidth=2)
plt.grid()
plt.title('Boxplot for Avg. Area Income')
plt.xlabel('X-Axis')
plt.ylabel('Avg. Area Income')
plt.yticks(np.arange(0, 100000, 5000))
plt.show()

# %% [markdown]
# Correlational Matrix

# %%
numerical_data = data.drop(columns = "Address", axis =1)
numerical_data.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.003628
# Avg. Area House Age                  -0.003628             1.000000
# Avg. Area Number of Rooms            -0.014357            -0.007505
# Avg. Area Number of Bedrooms          0.015439             0.005958
# Area Population                      -0.012452            -0.018269
# Price                                 0.627359             0.458764
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.014357
# Avg. Area House Age                           -0.007505
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462815
# Area Population                                0.003447
# Price                                          0.340312
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
sns.heatmap(numerical_data.corr(), annot = True)
# Out:
# <Axes: >

# %%
numerical_data.corr()['Price']
# Out:
# Avg. Area Income                0.627359
# Avg. Area House Age             0.458764
# Avg. Area Number of Rooms       0.340312
# Avg. Area Number of Bedrooms    0.170103
# Area Population                 0.415486
# Price                           1.000000
# Name: Price, dtype: float64

# %% [markdown]
# Encoding The Catergorical Data

# %%
categorical_data
# Out:
# Index(['Address'], dtype='object')

# %%
#using One-Hot Encoding Technique

one_hot_encoded = pd.get_dummies(data, columns=['Address'])

# %%
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
data.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
data[data.duplicated() == ()]
# Out:
# Empty DataFrame
# Columns: [Avg. Area Income, Avg. Area House Age, Avg. Area Number of Rooms, Avg. Area Number of Bedrooms, Area Population, Price, Address]
# Index: []

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Checking Correlation Again

# %%
data.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.003628
# Avg. Area House Age                  -0.003628             1.000000
# Avg. Area Number of Rooms            -0.014357            -0.007505
# Avg. Area Number of Bedrooms          0.015439             0.005958
# Area Population                      -0.012452            -0.018269
# Price                                 0.627359             0.458764
# Address                               0.627359             0.458764
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.014357
# Avg. Area House Age                           -0.007505
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462815
# Area Population                                0.003447
# Price                                          0.340312
# ...

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <Axes: >

# %%
var = abs(data.corr()['Price'])
var.sort_values(ascending = False)
# Out:
# Price                           1.000000
# Address                         1.000000
# Avg. Area Income                0.627359
# Avg. Area House Age             0.458764
# Area Population                 0.415486
# Avg. Area Number of Rooms       0.340312
# Avg. Area Number of Bedrooms    0.170103
# Name: Price, dtype: float64

# %% [markdown]
# Model Building

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
X = data[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
X
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...

# %%
Y = data[['Price']]
Y
# Out:
#              Price
# 0     1.059034e+06
# 1     1.505891e+06
# 2     1.058988e+06
# 3     1.260617e+06
# 4     6.309435e+05
# ...            ...
# 4995  1.060194e+06
# 4996  1.482618e+06
# 4997  1.030730e+06
# 4998  1.198657e+06
# 4999  1.298950e+06
#
# [4955 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state= 0)

# %%
X_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2171      67548.168102             5.760580                   8.194381
# 169       62784.332948             7.572350                   4.652718
# 3217      62635.259924             4.373087                   6.571057
# 852       73540.628940             4.421747                   7.049998
# 4167      53056.921041             5.180244                   9.536239
# ...                ...                  ...                        ...
# 4976      75046.313791             5.351169                   7.797825
# 3293      70825.696697             6.202613                   6.849371
# 1669      78241.075381             5.642007                   8.983474
# 2632      83016.431448             6.817154                   6.313062
# 2758      65531.109061             6.483332                   5.564653
#
#       Avg. Area Number of Bedrooms  Area Population
# 2171                          3.40     50213.738556
# ...

# %%
X_test
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2564      67535.207570             6.798691                   6.469379
# 450       61215.576611             7.488369                   8.791775
# 4814      82389.522278             5.012767                   7.155825
# 545       76259.825224             4.946108                   7.124519
# 1283      65659.586984             7.155653                   4.620870
# ...                ...                  ...                        ...
# 4804      66407.240468             4.473981                   5.345303
# 2910      71499.806645             5.533016                   6.767607
# 4962      88470.868056             7.419982                   6.872380
# 31        68652.609211             6.124342                   6.290820
# 4441      44048.456688             6.870972                   8.217177
#
#       Avg. Area Number of Bedrooms  Area Population
# 2564                          2.02     32375.826255
# ...

# %%
Y_train
# Out:
#              Price
# 2171  1.432903e+06
# 169   1.007479e+06
# 3217  4.619122e+05
# 852   9.361485e+05
# 4167  1.186663e+06
# ...            ...
# 4976  1.340344e+06
# 3293  1.603944e+06
# 1669  1.160146e+06
# 2632  1.689512e+06
# 2758  1.111711e+06
#
# [3964 rows x 1 columns]

# %%
Y_test
# Out:
#              Price
# 2564  1.074263e+06
# 450   1.465120e+06
# 4814  1.299925e+06
# 545   1.070240e+06
# 1283  9.809832e+05
# ...            ...
# 4804  6.260859e+05
# 2910  1.035977e+06
# 4962  1.955254e+06
# 31    1.170721e+06
# 4441  1.028275e+06
#
# [991 rows x 1 columns]

# %%
model=LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_train = model.predict(X_train)
Y_pred_test = model.predict(X_test)

# %%
X_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2171      67548.168102             5.760580                   8.194381
# 169       62784.332948             7.572350                   4.652718
# 3217      62635.259924             4.373087                   6.571057
# 852       73540.628940             4.421747                   7.049998
# 4167      53056.921041             5.180244                   9.536239
# ...                ...                  ...                        ...
# 4976      75046.313791             5.351169                   7.797825
# 3293      70825.696697             6.202613                   6.849371
# 1669      78241.075381             5.642007                   8.983474
# 2632      83016.431448             6.817154                   6.313062
# 2758      65531.109061             6.483332                   5.564653
#
#       Avg. Area Number of Bedrooms  Area Population
# 2171                          3.40     50213.738556
# ...

# %%
Y_train
# Out:
#              Price
# 2171  1.432903e+06
# 169   1.007479e+06
# 3217  4.619122e+05
# 852   9.361485e+05
# 4167  1.186663e+06
# ...            ...
# 4976  1.340344e+06
# 3293  1.603944e+06
# 1669  1.160146e+06
# 2632  1.689512e+06
# 2758  1.111711e+06
#
# [3964 rows x 1 columns]

# %%
Y_pred_train
# Out:
# array([[1529870.27185885],
#        [1074143.80125891],
#        [ 606644.75997194],
#        ...,
#        [1392378.27040657],
#        [1570392.28643949],
#        [1125353.13062927]])

# %%
Y_test
# Out:
#              Price
# 2564  1.074263e+06
# 450   1.465120e+06
# 4814  1.299925e+06
# 545   1.070240e+06
# 1283  9.809832e+05
# ...            ...
# 4804  6.260859e+05
# 2910  1.035977e+06
# 4962  1.955254e+06
# 31    1.170721e+06
# 4441  1.028275e+06
#
# [991 rows x 1 columns]

# %%
Y_pred_test
# Out:
# array([[1221969.14883456],
#        [1551039.99692683],
#        [1333985.13761248],
#        [ 984114.71169817],
#        [1140097.37012873],
#        [ 509770.15725537],
#        [1110313.81958616],
#        [1356369.54745911],
#        [1516436.36746313],
#        [1022825.29510855],
#        [1324014.51589763],
#        [1375924.34167633],
#        [ 985536.86059713],
#        [ 888457.43022449],
#        [1305900.89809767],
#        [1395347.89051745],
#        [1033126.56667615],
#        [ 951354.40540045],
#        [1227488.34261647],
#        [1073691.98421661],
#        [1462629.72815241],
#        [1071583.70298758],
#        [1301979.37430731],
#        [ 962281.8832653 ],
#        [1504877.42206976],
#        [1096940.59146479],
#        [1278472.39945265],
#        [1384812.96843577],
#        [1708423.02854643],
#        [1396446.56263228],
#        [ 999264.67156154],
#        [ 833490.25220858],
#        [1751583.06234341],
#        [1516311.55949157],
# ...

# %%
mcf = model.coef_
mcf
# Out:
# array([[2.16007156e+01, 1.66851273e+05, 1.20336824e+05, 2.08711460e+03,
#         1.51570290e+01]])

# %%
X.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population'],
#       dtype='object')

# %%
pd.DataFrame(mcf, columns = X.columns, index = ["Coefficients"])
# Out:
#               Avg. Area Income  Avg. Area House Age  \
# Coefficients         21.600716        166851.272565
#
#               Avg. Area Number of Rooms  Avg. Area Number of Bedrooms  \
# Coefficients              120336.823776                   2087.114599
#
#               Area Population
# Coefficients        15.157029

# %% [markdown]
# Scatter Plots

# %%
#for Training Data

# %%
plt.scatter(Y_train, Y_pred_train, color = 'm', label = "Actual Price", alpha = 0.2)
plt.plot([Y_train.min(), Y_train.max()], [Y_train.min(), Y_train.max()], 'k--', color = 'Black', lw = 2, label = "Predicted Price")
plt.title('Scatter Plot for Training Data')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.legend()
plt.show()

# %%
#for test data

# %%
plt.scatter(Y_test, Y_pred_test, color='m', label='Actual Price', alpha = 0.3)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()],'k--', color='k', lw=3, label="Predicted price")
plt.title('Scatter Plot for Test Data')
plt.xlabel('Actual price')
plt.ylabel('Predicted price')
plt.legend()
plt.show()

# %% [markdown]
# Evaluation Metrics

# %%
#for training data

# %%
def training_evaluation(actual, predicted):
    
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    mae = mean_absolute_error(actual, predicted)
    r2 = r2_score(actual, predicted)
    
    
    print(f'MSE: {mse}')
    print(f'RMSE: {rmse}')
    print(f'MAE: {mae}')
    print(f'R2_Score: {r2}')

# %%
training_evaluation(Y_train, Y_pred_train)
# Out:
# MSE: 10199610804.052248
# RMSE: 100993.12255818337
# MAE: 81401.93605735265
# R2_Score: 0.9163658230850925

# %%
#for testing data

# %%
def test_evaluation(actual, predicted):
    
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    mae = mean_absolute_error(actual, predicted)
    r2 = r2_score(actual, predicted)
    
    
    print(f'MSE: {mse}')
    print(f'RMSE: {rmse}')
    print(f'MAE: {mae}')
    print(f'R2_Score: {r2}')

# %%
test_evaluation(Y_test, Y_pred_test)
# Out:
# MSE: 10029174690.378569
# RMSE: 100145.7672114931
# MAE: 80122.18099303529
# R2_Score: 0.9152596214050269
